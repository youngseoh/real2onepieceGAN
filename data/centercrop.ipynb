# %%
import cv2
import os

def center_crop(image, size=(256, 256)):
    height, width, _ = image.shape
    new_width, new_height = size

    left = (width - new_width) // 2
    top = (height - new_height) // 2
    right = left + new_width
    bottom = top + new_height

    return image[top:bottom, left:right]

def crop_images_in_directory(input_dir, output_dir, size=(256, 256)):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    for filename in os.listdir(input_dir):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            image_path = os.path.join(input_dir, filename)
            img = cv2.imread(image_path)
            if img is not None:
                cropped_img = center_crop(img, size)
                output_path = os.path.join(output_dir, filename)
                cv2.imwrite(output_path, cropped_img)
                print(f"Processed and saved: {output_path}")
            else:
                print(f"Failed to load: {image_path}")

# Example usage
input_directory = "output_images_1"
output_directory = "output_images_1_crop"
crop_images_in_directory(input_directory, output_directory)
# Out:
# Processed and saved: output_images_1_crop\scene_001.jpg
# Processed and saved: output_images_1_crop\scene_002.jpg
# Processed and saved: output_images_1_crop\scene_003.jpg
# Processed and saved: output_images_1_crop\scene_004.jpg
# Processed and saved: output_images_1_crop\scene_005.jpg
# Processed and saved: output_images_1_crop\scene_006.jpg
# Processed and saved: output_images_1_crop\scene_007.jpg
# Processed and saved: output_images_1_crop\scene_008.jpg
# Processed and saved: output_images_1_crop\scene_009.jpg
# Processed and saved: output_images_1_crop\scene_010.jpg
# Processed and saved: output_images_1_crop\scene_011.jpg
# Processed and saved: output_images_1_crop\scene_012.jpg
# Processed and saved: output_images_1_crop\scene_013.jpg
# Processed and saved: output_images_1_crop\scene_014.jpg
# Processed and saved: output_images_1_crop\scene_015.jpg
# Processed and saved: output_images_1_crop\scene_016.jpg
# Processed and saved: output_images_1_crop\scene_017.jpg
# Processed and saved: output_images_1_crop\scene_018.jpg
# Processed and saved: output_images_1_crop\scene_019.jpg
# Processed and saved: output_images_1_crop\scene_020.jpg
# Processed and saved: output_images_1_crop\scene_021.jpg
# Processed and saved: output_images_1_crop\scene_022.jpg
# Processed and saved: output_images_1_crop\scene_023.jpg
# Processed and saved: output_images_1_crop\scene_024.jpg
# Processed and saved: output_images_1_crop\scene_025.jpg
# Processed and saved: output_images_1_crop\scene_026.jpg
# Processed and saved: output_images_1_crop\scene_027.jpg
# Processed and saved: output_images_1_crop\scene_028.jpg
# Processed and saved: output_images_1_crop\scene_029.jpg
# Processed and saved: output_images_1_crop\scene_030.jpg
# Processed and saved: output_images_1_crop\scene_031.jpg
# Processed and saved: output_images_1_crop\scene_032.jpg
# Processed and saved: output_images_1_crop\scene_033.jpg
# Processed and saved: output_images_1_crop\scene_034.jpg
# Processed and saved: output_images_1_crop\scene_035.jpg
# Processed and saved: output_images_1_crop\scene_036.jpg
# Processed and saved: output_images_1_crop\scene_037.jpg
# Processed and saved: output_images_1_crop\scene_038.jpg
# Processed and saved: output_images_1_crop\scene_039.jpg
# Processed and saved: output_images_1_crop\scene_040.jpg
# Processed and saved: output_images_1_crop\scene_041.jpg
# Processed and saved: output_images_1_crop\scene_042.jpg
# Processed and saved: output_images_1_crop\scene_043.jpg
# Processed and saved: output_images_1_crop\scene_044.jpg
# Processed and saved: output_images_1_crop\scene_045.jpg
# Processed and saved: output_images_1_crop\scene_046.jpg
# Processed and saved: output_images_1_crop\scene_047.jpg
# Processed and saved: output_images_1_crop\scene_048.jpg
# Processed and saved: output_images_1_crop\scene_049.jpg
# Processed and saved: output_images_1_crop\scene_050.jpg
# Processed and saved: output_images_1_crop\scene_051.jpg
# Processed and saved: output_images_1_crop\scene_052.jpg
# Processed and saved: output_images_1_crop\scene_053.jpg
# Processed and saved: output_images_1_crop\scene_054.jpg
# Processed and saved: output_images_1_crop\scene_055.jpg
# Processed and saved: output_images_1_crop\scene_056.jpg
# Processed and saved: output_images_1_crop\scene_057.jpg
# Processed and saved: output_images_1_crop\scene_058.jpg
# Processed and saved: output_images_1_crop\scene_059.jpg
# Processed and saved: output_images_1_crop\scene_060.jpg
# Processed and saved: output_images_1_crop\scene_061.jpg
# Processed and saved: output_images_1_crop\scene_062.jpg
# Processed and saved: output_images_1_crop\scene_063.jpg
# Processed and saved: output_images_1_crop\scene_064.jpg
# Processed and saved: output_images_1_crop\scene_065.jpg
# Processed and saved: output_images_1_crop\scene_066.jpg
# Processed and saved: output_images_1_crop\scene_067.jpg
# Processed and saved: output_images_1_crop\scene_068.jpg
# Processed and saved: output_images_1_crop\scene_069.jpg
# Processed and saved: output_images_1_crop\scene_070.jpg
# Processed and saved: output_images_1_crop\scene_071.jpg
# Processed and saved: output_images_1_crop\scene_072.jpg
# Processed and saved: output_images_1_crop\scene_073.jpg
# Processed and saved: output_images_1_crop\scene_074.jpg
# Processed and saved: output_images_1_crop\scene_075.jpg
# Processed and saved: output_images_1_crop\scene_076.jpg
# Processed and saved: output_images_1_crop\scene_077.jpg
# Processed and saved: output_images_1_crop\scene_078.jpg
# Processed and saved: output_images_1_crop\scene_079.jpg
# Processed and saved: output_images_1_crop\scene_080.jpg
# Processed and saved: output_images_1_crop\scene_081.jpg
# Processed and saved: output_images_1_crop\scene_082.jpg
# Processed and saved: output_images_1_crop\scene_083.jpg
# Processed and saved: output_images_1_crop\scene_084.jpg
# Processed and saved: output_images_1_crop\scene_085.jpg
# Processed and saved: output_images_1_crop\scene_086.jpg
# Processed and saved: output_images_1_crop\scene_087.jpg
# Processed and saved: output_images_1_crop\scene_088.jpg
# Processed and saved: output_images_1_crop\scene_089.jpg
# Processed and saved: output_images_1_crop\scene_090.jpg
# Processed and saved: output_images_1_crop\scene_091.jpg
# Processed and saved: output_images_1_crop\scene_092.jpg
# Processed and saved: output_images_1_crop\scene_093.jpg
# Processed and saved: output_images_1_crop\scene_094.jpg
# Processed and saved: output_images_1_crop\scene_095.jpg
# Processed and saved: output_images_1_crop\scene_096.jpg
# Processed and saved: output_images_1_crop\scene_097.jpg
# Processed and saved: output_images_1_crop\scene_098.jpg
# Processed and saved: output_images_1_crop\scene_099.jpg
# Processed and saved: output_images_1_crop\scene_100.jpg
# Processed and saved: output_images_1_crop\scene_101.jpg
# Processed and saved: output_images_1_crop\scene_102.jpg
# Processed and saved: output_images_1_crop\scene_103.jpg
# Processed and saved: output_images_1_crop\scene_104.jpg
# Processed and saved: output_images_1_crop\scene_105.jpg
# Processed and saved: output_images_1_crop\scene_106.jpg
# Processed and saved: output_images_1_crop\scene_107.jpg
# Processed and saved: output_images_1_crop\scene_108.jpg
# Processed and saved: output_images_1_crop\scene_109.jpg
# Processed and saved: output_images_1_crop\scene_110.jpg
# Processed and saved: output_images_1_crop\scene_111.jpg
# Processed and saved: output_images_1_crop\scene_112.jpg
# Processed and saved: output_images_1_crop\scene_113.jpg
# Processed and saved: output_images_1_crop\scene_114.jpg
# Processed and saved: output_images_1_crop\scene_115.jpg
# Processed and saved: output_images_1_crop\scene_116.jpg
# Processed and saved: output_images_1_crop\scene_117.jpg
# Processed and saved: output_images_1_crop\scene_118.jpg
# Processed and saved: output_images_1_crop\scene_119.jpg
# Processed and saved: output_images_1_crop\scene_120.jpg
# Processed and saved: output_images_1_crop\scene_121.jpg
# Processed and saved: output_images_1_crop\scene_122.jpg
# Processed and saved: output_images_1_crop\scene_123.jpg
# Processed and saved: output_images_1_crop\scene_124.jpg
# Processed and saved: output_images_1_crop\scene_125.jpg
# Processed and saved: output_images_1_crop\scene_126.jpg
# Processed and saved: output_images_1_crop\scene_127.jpg
# Processed and saved: output_images_1_crop\scene_128.jpg
# Processed and saved: output_images_1_crop\scene_129.jpg
# Processed and saved: output_images_1_crop\scene_130.jpg
# Processed and saved: output_images_1_crop\scene_131.jpg
# Processed and saved: output_images_1_crop\scene_132.jpg
# Processed and saved: output_images_1_crop\scene_133.jpg
# Processed and saved: output_images_1_crop\scene_134.jpg
# Processed and saved: output_images_1_crop\scene_135.jpg
# Processed and saved: output_images_1_crop\scene_136.jpg
# Processed and saved: output_images_1_crop\scene_137.jpg
# Processed and saved: output_images_1_crop\scene_138.jpg
# Processed and saved: output_images_1_crop\scene_139.jpg
# Processed and saved: output_images_1_crop\scene_140.jpg
# Processed and saved: output_images_1_crop\scene_141.jpg
# Processed and saved: output_images_1_crop\scene_142.jpg
# Processed and saved: output_images_1_crop\scene_143.jpg
# Processed and saved: output_images_1_crop\scene_144.jpg
# Processed and saved: output_images_1_crop\scene_145.jpg
# Processed and saved: output_images_1_crop\scene_146.jpg
# Processed and saved: output_images_1_crop\scene_147.jpg
# Processed and saved: output_images_1_crop\scene_148.jpg
# Processed and saved: output_images_1_crop\scene_149.jpg
# Processed and saved: output_images_1_crop\scene_150.jpg
# Processed and saved: output_images_1_crop\scene_151.jpg
# Processed and saved: output_images_1_crop\scene_152.jpg
# Processed and saved: output_images_1_crop\scene_153.jpg
# Processed and saved: output_images_1_crop\scene_154.jpg
# Processed and saved: output_images_1_crop\scene_155.jpg
# Processed and saved: output_images_1_crop\scene_156.jpg
# Processed and saved: output_images_1_crop\scene_157.jpg
# Processed and saved: output_images_1_crop\scene_158.jpg
# Processed and saved: output_images_1_crop\scene_159.jpg
# Processed and saved: output_images_1_crop\scene_160.jpg
# Processed and saved: output_images_1_crop\scene_161.jpg
# Processed and saved: output_images_1_crop\scene_162.jpg
# Processed and saved: output_images_1_crop\scene_163.jpg
# Processed and saved: output_images_1_crop\scene_164.jpg
# Processed and saved: output_images_1_crop\scene_165.jpg
# Processed and saved: output_images_1_crop\scene_166.jpg
# Processed and saved: output_images_1_crop\scene_167.jpg
# Processed and saved: output_images_1_crop\scene_168.jpg
# Processed and saved: output_images_1_crop\scene_169.jpg
# Processed and saved: output_images_1_crop\scene_170.jpg
# Processed and saved: output_images_1_crop\scene_171.jpg
# Processed and saved: output_images_1_crop\scene_172.jpg
# Processed and saved: output_images_1_crop\scene_173.jpg
# Processed and saved: output_images_1_crop\scene_174.jpg
# Processed and saved: output_images_1_crop\scene_175.jpg
# Processed and saved: output_images_1_crop\scene_176.jpg
# Processed and saved: output_images_1_crop\scene_177.jpg
# Processed and saved: output_images_1_crop\scene_178.jpg
# Processed and saved: output_images_1_crop\scene_179.jpg
# Processed and saved: output_images_1_crop\scene_180.jpg
# Processed and saved: output_images_1_crop\scene_181.jpg
# Processed and saved: output_images_1_crop\scene_182.jpg
# Processed and saved: output_images_1_crop\scene_183.jpg
# Processed and saved: output_images_1_crop\scene_184.jpg
# Processed and saved: output_images_1_crop\scene_185.jpg
# Processed and saved: output_images_1_crop\scene_186.jpg
# Processed and saved: output_images_1_crop\scene_187.jpg
# Processed and saved: output_images_1_crop\scene_188.jpg
# Processed and saved: output_images_1_crop\scene_189.jpg
# Processed and saved: output_images_1_crop\scene_190.jpg
# Processed and saved: output_images_1_crop\scene_191.jpg
# Processed and saved: output_images_1_crop\scene_192.jpg
# Processed and saved: output_images_1_crop\scene_193.jpg
# Processed and saved: output_images_1_crop\scene_194.jpg
# Processed and saved: output_images_1_crop\scene_195.jpg
# Processed and saved: output_images_1_crop\scene_196.jpg
# Processed and saved: output_images_1_crop\scene_197.jpg
# Processed and saved: output_images_1_crop\scene_198.jpg
# Processed and saved: output_images_1_crop\scene_199.jpg
# Processed and saved: output_images_1_crop\scene_200.jpg
# Processed and saved: output_images_1_crop\scene_201.jpg
# Processed and saved: output_images_1_crop\scene_202.jpg
# Processed and saved: output_images_1_crop\scene_203.jpg
# Processed and saved: output_images_1_crop\scene_204.jpg
# Processed and saved: output_images_1_crop\scene_205.jpg
# Processed and saved: output_images_1_crop\scene_206.jpg
# Processed and saved: output_images_1_crop\scene_207.jpg
# Processed and saved: output_images_1_crop\scene_208.jpg
# Processed and saved: output_images_1_crop\scene_209.jpg
# Processed and saved: output_images_1_crop\scene_210.jpg
# Processed and saved: output_images_1_crop\scene_211.jpg
# Processed and saved: output_images_1_crop\scene_212.jpg
# Processed and saved: output_images_1_crop\scene_213.jpg
# Processed and saved: output_images_1_crop\scene_214.jpg
# Processed and saved: output_images_1_crop\scene_215.jpg
# Processed and saved: output_images_1_crop\scene_216.jpg
# Processed and saved: output_images_1_crop\scene_217.jpg
# Processed and saved: output_images_1_crop\scene_218.jpg
# Processed and saved: output_images_1_crop\scene_219.jpg
# Processed and saved: output_images_1_crop\scene_220.jpg
# Processed and saved: output_images_1_crop\scene_221.jpg
# Processed and saved: output_images_1_crop\scene_222.jpg
# Processed and saved: output_images_1_crop\scene_223.jpg
# Processed and saved: output_images_1_crop\scene_224.jpg
# Processed and saved: output_images_1_crop\scene_225.jpg
# Processed and saved: output_images_1_crop\scene_226.jpg
# Processed and saved: output_images_1_crop\scene_227.jpg
# Processed and saved: output_images_1_crop\scene_228.jpg
# Processed and saved: output_images_1_crop\scene_229.jpg
# Processed and saved: output_images_1_crop\scene_230.jpg
# Processed and saved: output_images_1_crop\scene_231.jpg
# Processed and saved: output_images_1_crop\scene_232.jpg
# Processed and saved: output_images_1_crop\scene_233.jpg
# Processed and saved: output_images_1_crop\scene_234.jpg
# Processed and saved: output_images_1_crop\scene_235.jpg
# Processed and saved: output_images_1_crop\scene_236.jpg
# Processed and saved: output_images_1_crop\scene_237.jpg
# Processed and saved: output_images_1_crop\scene_238.jpg
# Processed and saved: output_images_1_crop\scene_239.jpg
# Processed and saved: output_images_1_crop\scene_240.jpg
# Processed and saved: output_images_1_crop\scene_241.jpg
# Processed and saved: output_images_1_crop\scene_242.jpg
# Processed and saved: output_images_1_crop\scene_243.jpg
# Processed and saved: output_images_1_crop\scene_244.jpg
# Processed and saved: output_images_1_crop\scene_245.jpg
# Processed and saved: output_images_1_crop\scene_246.jpg
# Processed and saved: output_images_1_crop\scene_247.jpg
# Processed and saved: output_images_1_crop\scene_248.jpg
# Processed and saved: output_images_1_crop\scene_249.jpg
# Processed and saved: output_images_1_crop\scene_250.jpg
# Processed and saved: output_images_1_crop\scene_251.jpg
# Processed and saved: output_images_1_crop\scene_252.jpg
# Processed and saved: output_images_1_crop\scene_253.jpg
# Processed and saved: output_images_1_crop\scene_254.jpg
# Processed and saved: output_images_1_crop\scene_255.jpg
# Processed and saved: output_images_1_crop\scene_256.jpg
# Processed and saved: output_images_1_crop\scene_257.jpg
# Processed and saved: output_images_1_crop\scene_258.jpg
# Processed and saved: output_images_1_crop\scene_259.jpg
# Processed and saved: output_images_1_crop\scene_260.jpg
# Processed and saved: output_images_1_crop\scene_261.jpg
# Processed and saved: output_images_1_crop\scene_262.jpg
# Processed and saved: output_images_1_crop\scene_263.jpg
# Processed and saved: output_images_1_crop\scene_264.jpg
# Processed and saved: output_images_1_crop\scene_265.jpg
# Processed and saved: output_images_1_crop\scene_266.jpg
# Processed and saved: output_images_1_crop\scene_267.jpg
# Processed and saved: output_images_1_crop\scene_268.jpg
# Processed and saved: output_images_1_crop\scene_269.jpg
# Processed and saved: output_images_1_crop\scene_270.jpg
# Processed and saved: output_images_1_crop\scene_271.jpg
# Processed and saved: output_images_1_crop\scene_272.jpg
# Processed and saved: output_images_1_crop\scene_273.jpg
# Processed and saved: output_images_1_crop\scene_274.jpg
# Processed and saved: output_images_1_crop\scene_275.jpg
# Processed and saved: output_images_1_crop\scene_276.jpg
# Processed and saved: output_images_1_crop\scene_277.jpg
# Processed and saved: output_images_1_crop\scene_278.jpg
# Processed and saved: output_images_1_crop\scene_279.jpg
# Processed and saved: output_images_1_crop\scene_280.jpg
# Processed and saved: output_images_1_crop\scene_281.jpg
# Processed and saved: output_images_1_crop\scene_282.jpg
# Processed and saved: output_images_1_crop\scene_283.jpg
# Processed and saved: output_images_1_crop\scene_284.jpg
# Processed and saved: output_images_1_crop\scene_285.jpg
# Processed and saved: output_images_1_crop\scene_286.jpg
# Processed and saved: output_images_1_crop\scene_287.jpg
# Processed and saved: output_images_1_crop\scene_288.jpg
# Processed and saved: output_images_1_crop\scene_289.jpg
# Processed and saved: output_images_1_crop\scene_290.jpg
# Processed and saved: output_images_1_crop\scene_291.jpg
# Processed and saved: output_images_1_crop\scene_292.jpg
# Processed and saved: output_images_1_crop\scene_293.jpg
# Processed and saved: output_images_1_crop\scene_294.jpg
# Processed and saved: output_images_1_crop\scene_295.jpg
# Processed and saved: output_images_1_crop\scene_296.jpg
# Processed and saved: output_images_1_crop\scene_297.jpg
# Processed and saved: output_images_1_crop\scene_298.jpg
# Processed and saved: output_images_1_crop\scene_299.jpg
# Processed and saved: output_images_1_crop\scene_300.jpg
# Processed and saved: output_images_1_crop\scene_301.jpg
# Processed and saved: output_images_1_crop\scene_302.jpg
# Processed and saved: output_images_1_crop\scene_303.jpg
# Processed and saved: output_images_1_crop\scene_304.jpg
# Processed and saved: output_images_1_crop\scene_305.jpg
# Processed and saved: output_images_1_crop\scene_306.jpg
# Processed and saved: output_images_1_crop\scene_307.jpg
# Processed and saved: output_images_1_crop\scene_308.jpg
# Processed and saved: output_images_1_crop\scene_309.jpg
# Processed and saved: output_images_1_crop\scene_310.jpg
# Processed and saved: output_images_1_crop\scene_311.jpg
# Processed and saved: output_images_1_crop\scene_312.jpg
# Processed and saved: output_images_1_crop\scene_313.jpg
# Processed and saved: output_images_1_crop\scene_314.jpg
# Processed and saved: output_images_1_crop\scene_315.jpg
# Processed and saved: output_images_1_crop\scene_316.jpg
# Processed and saved: output_images_1_crop\scene_317.jpg
# Processed and saved: output_images_1_crop\scene_318.jpg
# Processed and saved: output_images_1_crop\scene_319.jpg
# Processed and saved: output_images_1_crop\scene_320.jpg
# Processed and saved: output_images_1_crop\scene_321.jpg
# Processed and saved: output_images_1_crop\scene_322.jpg
# Processed and saved: output_images_1_crop\scene_323.jpg
# Processed and saved: output_images_1_crop\scene_324.jpg
# Processed and saved: output_images_1_crop\scene_325.jpg
# Processed and saved: output_images_1_crop\scene_326.jpg
# Processed and saved: output_images_1_crop\scene_327.jpg
# Processed and saved: output_images_1_crop\scene_328.jpg
# Processed and saved: output_images_1_crop\scene_329.jpg
# Processed and saved: output_images_1_crop\scene_330.jpg
# Processed and saved: output_images_1_crop\scene_331.jpg
# Processed and saved: output_images_1_crop\scene_332.jpg
# Processed and saved: output_images_1_crop\scene_333.jpg
# Processed and saved: output_images_1_crop\scene_334.jpg
# Processed and saved: output_images_1_crop\scene_335.jpg
# Processed and saved: output_images_1_crop\scene_336.jpg
# Processed and saved: output_images_1_crop\scene_337.jpg
# Processed and saved: output_images_1_crop\scene_338.jpg
# Processed and saved: output_images_1_crop\scene_339.jpg
# Processed and saved: output_images_1_crop\scene_340.jpg
# Processed and saved: output_images_1_crop\scene_341.jpg
# Processed and saved: output_images_1_crop\scene_342.jpg
# Processed and saved: output_images_1_crop\scene_343.jpg
# Processed and saved: output_images_1_crop\scene_344.jpg
# Processed and saved: output_images_1_crop\scene_345.jpg
# Processed and saved: output_images_1_crop\scene_346.jpg
# Processed and saved: output_images_1_crop\scene_347.jpg
# Processed and saved: output_images_1_crop\scene_348.jpg
# Processed and saved: output_images_1_crop\scene_349.jpg
# Processed and saved: output_images_1_crop\scene_350.jpg
# Processed and saved: output_images_1_crop\scene_351.jpg
# Processed and saved: output_images_1_crop\scene_352.jpg
# Processed and saved: output_images_1_crop\scene_353.jpg
# Processed and saved: output_images_1_crop\scene_354.jpg
# Processed and saved: output_images_1_crop\scene_355.jpg
# Processed and saved: output_images_1_crop\scene_356.jpg
# Processed and saved: output_images_1_crop\scene_357.jpg
# Processed and saved: output_images_1_crop\scene_358.jpg
# Processed and saved: output_images_1_crop\scene_359.jpg
# Processed and saved: output_images_1_crop\scene_360.jpg
# Processed and saved: output_images_1_crop\scene_361.jpg
# Processed and saved: output_images_1_crop\scene_362.jpg
# Processed and saved: output_images_1_crop\scene_363.jpg
# Processed and saved: output_images_1_crop\scene_364.jpg
# Processed and saved: output_images_1_crop\scene_365.jpg
# Processed and saved: output_images_1_crop\scene_366.jpg
# Processed and saved: output_images_1_crop\scene_367.jpg
# Processed and saved: output_images_1_crop\scene_368.jpg
# Processed and saved: output_images_1_crop\scene_369.jpg
# Processed and saved: output_images_1_crop\scene_370.jpg
# Processed and saved: output_images_1_crop\scene_371.jpg
# Processed and saved: output_images_1_crop\scene_372.jpg
# Processed and saved: output_images_1_crop\scene_373.jpg
# Processed and saved: output_images_1_crop\scene_374.jpg
# Processed and saved: output_images_1_crop\scene_375.jpg
# Processed and saved: output_images_1_crop\scene_376.jpg
# Processed and saved: output_images_1_crop\scene_377.jpg
# Processed and saved: output_images_1_crop\scene_378.jpg
# Processed and saved: output_images_1_crop\scene_379.jpg
# Processed and saved: output_images_1_crop\scene_380.jpg
# Processed and saved: output_images_1_crop\scene_381.jpg
# Processed and saved: output_images_1_crop\scene_382.jpg
# Processed and saved: output_images_1_crop\scene_383.jpg
# Processed and saved: output_images_1_crop\scene_384.jpg
# Processed and saved: output_images_1_crop\scene_385.jpg
# Processed and saved: output_images_1_crop\scene_386.jpg
# Processed and saved: output_images_1_crop\scene_387.jpg
# Processed and saved: output_images_1_crop\scene_388.jpg
# Processed and saved: output_images_1_crop\scene_389.jpg
# Processed and saved: output_images_1_crop\scene_390.jpg
# Processed and saved: output_images_1_crop\scene_391.jpg
# Processed and saved: output_images_1_crop\scene_392.jpg
# Processed and saved: output_images_1_crop\scene_393.jpg
# Processed and saved: output_images_1_crop\scene_394.jpg
# Processed and saved: output_images_1_crop\scene_395.jpg
# Processed and saved: output_images_1_crop\scene_396.jpg
# Processed and saved: output_images_1_crop\scene_397.jpg
# Processed and saved: output_images_1_crop\scene_398.jpg
# Processed and saved: output_images_1_crop\scene_399.jpg
# Processed and saved: output_images_1_crop\scene_400.jpg
# Processed and saved: output_images_1_crop\scene_401.jpg
# Processed and saved: output_images_1_crop\scene_402.jpg
# Processed and saved: output_images_1_crop\scene_403.jpg
# Processed and saved: output_images_1_crop\scene_404.jpg
# Processed and saved: output_images_1_crop\scene_405.jpg
# Processed and saved: output_images_1_crop\scene_406.jpg
# Processed and saved: output_images_1_crop\scene_407.jpg
# Processed and saved: output_images_1_crop\scene_408.jpg
# Processed and saved: output_images_1_crop\scene_409.jpg
# Processed and saved: output_images_1_crop\scene_410.jpg
# Processed and saved: output_images_1_crop\scene_411.jpg
# Processed and saved: output_images_1_crop\scene_412.jpg
# Processed and saved: output_images_1_crop\scene_413.jpg
# Processed and saved: output_images_1_crop\scene_414.jpg
# Processed and saved: output_images_1_crop\scene_415.jpg
# Processed and saved: output_images_1_crop\scene_416.jpg
# Processed and saved: output_images_1_crop\scene_417.jpg
# Processed and saved: output_images_1_crop\scene_418.jpg
# Processed and saved: output_images_1_crop\scene_419.jpg
# Processed and saved: output_images_1_crop\scene_420.jpg
# Processed and saved: output_images_1_crop\scene_421.jpg
# Processed and saved: output_images_1_crop\scene_422.jpg
# Processed and saved: output_images_1_crop\scene_423.jpg
# Processed and saved: output_images_1_crop\scene_424.jpg
# Processed and saved: output_images_1_crop\scene_425.jpg
# Processed and saved: output_images_1_crop\scene_426.jpg
# Processed and saved: output_images_1_crop\scene_427.jpg
# Processed and saved: output_images_1_crop\scene_428.jpg
# Processed and saved: output_images_1_crop\scene_429.jpg
# Processed and saved: output_images_1_crop\scene_430.jpg
# Processed and saved: output_images_1_crop\scene_431.jpg
# Processed and saved: output_images_1_crop\scene_432.jpg
# Processed and saved: output_images_1_crop\scene_433.jpg
# Processed and saved: output_images_1_crop\scene_434.jpg
# Processed and saved: output_images_1_crop\scene_435.jpg
# Processed and saved: output_images_1_crop\scene_436.jpg
# Processed and saved: output_images_1_crop\scene_437.jpg
# Processed and saved: output_images_1_crop\scene_438.jpg
# Processed and saved: output_images_1_crop\scene_439.jpg
# Processed and saved: output_images_1_crop\scene_440.jpg
# Processed and saved: output_images_1_crop\scene_441.jpg
# Processed and saved: output_images_1_crop\scene_442.jpg
# Processed and saved: output_images_1_crop\scene_443.jpg
# Processed and saved: output_images_1_crop\scene_444.jpg
# Processed and saved: output_images_1_crop\scene_445.jpg
# Processed and saved: output_images_1_crop\scene_446.jpg
# Processed and saved: output_images_1_crop\scene_447.jpg
# Processed and saved: output_images_1_crop\scene_448.jpg
# Processed and saved: output_images_1_crop\scene_449.jpg
# Processed and saved: output_images_1_crop\scene_450.jpg
# Processed and saved: output_images_1_crop\scene_451.jpg
# Processed and saved: output_images_1_crop\scene_452.jpg
# Processed and saved: output_images_1_crop\scene_453.jpg
# Processed and saved: output_images_1_crop\scene_454.jpg
# Processed and saved: output_images_1_crop\scene_455.jpg
# Processed and saved: output_images_1_crop\scene_456.jpg
# Processed and saved: output_images_1_crop\scene_457.jpg
# Processed and saved: output_images_1_crop\scene_458.jpg
# Processed and saved: output_images_1_crop\scene_459.jpg
# Processed and saved: output_images_1_crop\scene_460.jpg
# Processed and saved: output_images_1_crop\scene_461.jpg
# Processed and saved: output_images_1_crop\scene_462.jpg
# Processed and saved: output_images_1_crop\scene_463.jpg
# Processed and saved: output_images_1_crop\scene_464.jpg
# Processed and saved: output_images_1_crop\scene_465.jpg
# Processed and saved: output_images_1_crop\scene_466.jpg
# Processed and saved: output_images_1_crop\scene_467.jpg
# Processed and saved: output_images_1_crop\scene_468.jpg
# Processed and saved: output_images_1_crop\scene_469.jpg
# Processed and saved: output_images_1_crop\scene_470.jpg
# Processed and saved: output_images_1_crop\scene_471.jpg
# Processed and saved: output_images_1_crop\scene_472.jpg
# Processed and saved: output_images_1_crop\scene_473.jpg
# Processed and saved: output_images_1_crop\scene_474.jpg
# Processed and saved: output_images_1_crop\scene_475.jpg
# Processed and saved: output_images_1_crop\scene_476.jpg
# Processed and saved: output_images_1_crop\scene_477.jpg
# Processed and saved: output_images_1_crop\scene_478.jpg
# Processed and saved: output_images_1_crop\scene_479.jpg
# Processed and saved: output_images_1_crop\scene_480.jpg
# Processed and saved: output_images_1_crop\scene_481.jpg
# Processed and saved: output_images_1_crop\scene_482.jpg
# Processed and saved: output_images_1_crop\scene_483.jpg
# Processed and saved: output_images_1_crop\scene_484.jpg
# Processed and saved: output_images_1_crop\scene_485.jpg
# Processed and saved: output_images_1_crop\scene_486.jpg
# Processed and saved: output_images_1_crop\scene_487.jpg
# Processed and saved: output_images_1_crop\scene_488.jpg
# Processed and saved: output_images_1_crop\scene_489.jpg
# Processed and saved: output_images_1_crop\scene_490.jpg
# Processed and saved: output_images_1_crop\scene_491.jpg
# Processed and saved: output_images_1_crop\scene_492.jpg
# Processed and saved: output_images_1_crop\scene_493.jpg
# Processed and saved: output_images_1_crop\scene_494.jpg
# Processed and saved: output_images_1_crop\scene_495.jpg
# Processed and saved: output_images_1_crop\scene_496.jpg
# Processed and saved: output_images_1_crop\scene_497.jpg
# Processed and saved: output_images_1_crop\scene_498.jpg
# Processed and saved: output_images_1_crop\scene_499.jpg
# Processed and saved: output_images_1_crop\scene_500.jpg
# Processed and saved: output_images_1_crop\scene_501.jpg
# Processed and saved: output_images_1_crop\scene_502.jpg
# Processed and saved: output_images_1_crop\scene_503.jpg
# Processed and saved: output_images_1_crop\scene_504.jpg
# Processed and saved: output_images_1_crop\scene_505.jpg
# Processed and saved: output_images_1_crop\scene_506.jpg
# Processed and saved: output_images_1_crop\scene_507.jpg
# Processed and saved: output_images_1_crop\scene_508.jpg
# Processed and saved: output_images_1_crop\scene_509.jpg
# Processed and saved: output_images_1_crop\scene_510.jpg
# Processed and saved: output_images_1_crop\scene_511.jpg
# Processed and saved: output_images_1_crop\scene_512.jpg
# Processed and saved: output_images_1_crop\scene_513.jpg
# Processed and saved: output_images_1_crop\scene_514.jpg
# Processed and saved: output_images_1_crop\scene_515.jpg
# Processed and saved: output_images_1_crop\scene_516.jpg
# Processed and saved: output_images_1_crop\scene_517.jpg
# Processed and saved: output_images_1_crop\scene_518.jpg
# Processed and saved: output_images_1_crop\scene_519.jpg
# Processed and saved: output_images_1_crop\scene_520.jpg
# Processed and saved: output_images_1_crop\scene_521.jpg
# Processed and saved: output_images_1_crop\scene_522.jpg
# Processed and saved: output_images_1_crop\scene_523.jpg
# Processed and saved: output_images_1_crop\scene_524.jpg
# Processed and saved: output_images_1_crop\scene_525.jpg
# Processed and saved: output_images_1_crop\scene_526.jpg
# Processed and saved: output_images_1_crop\scene_527.jpg
# Processed and saved: output_images_1_crop\scene_528.jpg
# Processed and saved: output_images_1_crop\scene_529.jpg
# Processed and saved: output_images_1_crop\scene_530.jpg
# Processed and saved: output_images_1_crop\scene_531.jpg
# Processed and saved: output_images_1_crop\scene_532.jpg
# Processed and saved: output_images_1_crop\scene_533.jpg
# Processed and saved: output_images_1_crop\scene_534.jpg
# Processed and saved: output_images_1_crop\scene_535.jpg
# Processed and saved: output_images_1_crop\scene_536.jpg
# Processed and saved: output_images_1_crop\scene_537.jpg
# Processed and saved: output_images_1_crop\scene_538.jpg
# Processed and saved: output_images_1_crop\scene_539.jpg
# Processed and saved: output_images_1_crop\scene_540.jpg
# Processed and saved: output_images_1_crop\scene_541.jpg
# Processed and saved: output_images_1_crop\scene_542.jpg
# Processed and saved: output_images_1_crop\scene_543.jpg
# Processed and saved: output_images_1_crop\scene_544.jpg
# Processed and saved: output_images_1_crop\scene_545.jpg
# Processed and saved: output_images_1_crop\scene_546.jpg
# Processed and saved: output_images_1_crop\scene_547.jpg
# Processed and saved: output_images_1_crop\scene_548.jpg
# Processed and saved: output_images_1_crop\scene_549.jpg
# Processed and saved: output_images_1_crop\scene_550.jpg
# Processed and saved: output_images_1_crop\scene_551.jpg
# Processed and saved: output_images_1_crop\scene_552.jpg
# Processed and saved: output_images_1_crop\scene_553.jpg
# Processed and saved: output_images_1_crop\scene_554.jpg
# Processed and saved: output_images_1_crop\scene_555.jpg
# Processed and saved: output_images_1_crop\scene_556.jpg
# Processed and saved: output_images_1_crop\scene_557.jpg
# Processed and saved: output_images_1_crop\scene_558.jpg
# Processed and saved: output_images_1_crop\scene_559.jpg
# Processed and saved: output_images_1_crop\scene_560.jpg
# Processed and saved: output_images_1_crop\scene_561.jpg
# Processed and saved: output_images_1_crop\scene_562.jpg
# Processed and saved: output_images_1_crop\scene_563.jpg
# Processed and saved: output_images_1_crop\scene_564.jpg
# Processed and saved: output_images_1_crop\scene_565.jpg
# Processed and saved: output_images_1_crop\scene_566.jpg
# Processed and saved: output_images_1_crop\scene_567.jpg
# Processed and saved: output_images_1_crop\scene_568.jpg
# Processed and saved: output_images_1_crop\scene_569.jpg
# Processed and saved: output_images_1_crop\scene_570.jpg
# Processed and saved: output_images_1_crop\scene_571.jpg
# Processed and saved: output_images_1_crop\scene_572.jpg
# Processed and saved: output_images_1_crop\scene_573.jpg
# Processed and saved: output_images_1_crop\scene_574.jpg
# Processed and saved: output_images_1_crop\scene_575.jpg
# Processed and saved: output_images_1_crop\scene_576.jpg
# Processed and saved: output_images_1_crop\scene_577.jpg
# Processed and saved: output_images_1_crop\scene_578.jpg
# Processed and saved: output_images_1_crop\scene_579.jpg
# Processed and saved: output_images_1_crop\scene_580.jpg
# Processed and saved: output_images_1_crop\scene_581.jpg
# Processed and saved: output_images_1_crop\scene_582.jpg
# Processed and saved: output_images_1_crop\scene_583.jpg
# Processed and saved: output_images_1_crop\scene_584.jpg
# Processed and saved: output_images_1_crop\scene_585.jpg
# Processed and saved: output_images_1_crop\scene_586.jpg
# Processed and saved: output_images_1_crop\scene_587.jpg
# Processed and saved: output_images_1_crop\scene_588.jpg
# Processed and saved: output_images_1_crop\scene_589.jpg
# Processed and saved: output_images_1_crop\scene_590.jpg
# Processed and saved: output_images_1_crop\scene_591.jpg
# Processed and saved: output_images_1_crop\scene_592.jpg
# Processed and saved: output_images_1_crop\scene_593.jpg
# Processed and saved: output_images_1_crop\scene_594.jpg
# Processed and saved: output_images_1_crop\scene_595.jpg
# Processed and saved: output_images_1_crop\scene_596.jpg
# Processed and saved: output_images_1_crop\scene_597.jpg
# Processed and saved: output_images_1_crop\scene_598.jpg
# Processed and saved: output_images_1_crop\scene_599.jpg
# Processed and saved: output_images_1_crop\scene_600.jpg
# Processed and saved: output_images_1_crop\scene_601.jpg
# Processed and saved: output_images_1_crop\scene_602.jpg
# Processed and saved: output_images_1_crop\scene_603.jpg
# Processed and saved: output_images_1_crop\scene_604.jpg
# Processed and saved: output_images_1_crop\scene_605.jpg
# Processed and saved: output_images_1_crop\scene_606.jpg
# Processed and saved: output_images_1_crop\scene_607.jpg
# Processed and saved: output_images_1_crop\scene_608.jpg
# Processed and saved: output_images_1_crop\scene_609.jpg
# Processed and saved: output_images_1_crop\scene_610.jpg
# Processed and saved: output_images_1_crop\scene_611.jpg
# Processed and saved: output_images_1_crop\scene_612.jpg
# Processed and saved: output_images_1_crop\scene_613.jpg
# Processed and saved: output_images_1_crop\scene_614.jpg
# Processed and saved: output_images_1_crop\scene_615.jpg
# Processed and saved: output_images_1_crop\scene_616.jpg
# Processed and saved: output_images_1_crop\scene_617.jpg
# Processed and saved: output_images_1_crop\scene_618.jpg
# Processed and saved: output_images_1_crop\scene_619.jpg
# Processed and saved: output_images_1_crop\scene_620.jpg
# Processed and saved: output_images_1_crop\scene_621.jpg
# Processed and saved: output_images_1_crop\scene_622.jpg
# Processed and saved: output_images_1_crop\scene_623.jpg
# Processed and saved: output_images_1_crop\scene_624.jpg
# Processed and saved: output_images_1_crop\scene_625.jpg
# Processed and saved: output_images_1_crop\scene_626.jpg
# Processed and saved: output_images_1_crop\scene_627.jpg
# Processed and saved: output_images_1_crop\scene_628.jpg
# Processed and saved: output_images_1_crop\scene_629.jpg
# Processed and saved: output_images_1_crop\scene_630.jpg
# Processed and saved: output_images_1_crop\scene_631.jpg
# Processed and saved: output_images_1_crop\scene_632.jpg
# Processed and saved: output_images_1_crop\scene_633.jpg
# Processed and saved: output_images_1_crop\scene_634.jpg
# Processed and saved: output_images_1_crop\scene_635.jpg
# Processed and saved: output_images_1_crop\scene_636.jpg
# Processed and saved: output_images_1_crop\scene_637.jpg
# Processed and saved: output_images_1_crop\scene_638.jpg
# Processed and saved: output_images_1_crop\scene_639.jpg
# Processed and saved: output_images_1_crop\scene_640.jpg
# Processed and saved: output_images_1_crop\scene_641.jpg
# Processed and saved: output_images_1_crop\scene_642.jpg
# Processed and saved: output_images_1_crop\scene_643.jpg
# Processed and saved: output_images_1_crop\scene_644.jpg
# Processed and saved: output_images_1_crop\scene_645.jpg
# Processed and saved: output_images_1_crop\scene_646.jpg
# Processed and saved: output_images_1_crop\scene_647.jpg
# Processed and saved: output_images_1_crop\scene_648.jpg
# Processed and saved: output_images_1_crop\scene_649.jpg
# Processed and saved: output_images_1_crop\scene_650.jpg
# Processed and saved: output_images_1_crop\scene_651.jpg
# Processed and saved: output_images_1_crop\scene_652.jpg
# Processed and saved: output_images_1_crop\scene_653.jpg
# Processed and saved: output_images_1_crop\scene_654.jpg
# Processed and saved: output_images_1_crop\scene_655.jpg
# Processed and saved: output_images_1_crop\scene_656.jpg
# Processed and saved: output_images_1_crop\scene_657.jpg
# Processed and saved: output_images_1_crop\scene_658.jpg
# Processed and saved: output_images_1_crop\scene_659.jpg
# Processed and saved: output_images_1_crop\scene_660.jpg
# Processed and saved: output_images_1_crop\scene_661.jpg
# Processed and saved: output_images_1_crop\scene_662.jpg
# Processed and saved: output_images_1_crop\scene_663.jpg
# Processed and saved: output_images_1_crop\scene_664.jpg
# Processed and saved: output_images_1_crop\scene_665.jpg
# Processed and saved: output_images_1_crop\scene_666.jpg
# Processed and saved: output_images_1_crop\scene_667.jpg
# Processed and saved: output_images_1_crop\scene_668.jpg
# Processed and saved: output_images_1_crop\scene_669.jpg
# Processed and saved: output_images_1_crop\scene_670.jpg
# Processed and saved: output_images_1_crop\scene_671.jpg
# Processed and saved: output_images_1_crop\scene_672.jpg
# Processed and saved: output_images_1_crop\scene_673.jpg
# Processed and saved: output_images_1_crop\scene_674.jpg
# Processed and saved: output_images_1_crop\scene_675.jpg
# Processed and saved: output_images_1_crop\scene_676.jpg
# Processed and saved: output_images_1_crop\scene_677.jpg
# Processed and saved: output_images_1_crop\scene_678.jpg
# Processed and saved: output_images_1_crop\scene_679.jpg
# Processed and saved: output_images_1_crop\scene_680.jpg
# Processed and saved: output_images_1_crop\scene_681.jpg
# Processed and saved: output_images_1_crop\scene_682.jpg
# Processed and saved: output_images_1_crop\scene_683.jpg
# Processed and saved: output_images_1_crop\scene_684.jpg
# Processed and saved: output_images_1_crop\scene_685.jpg
# Processed and saved: output_images_1_crop\scene_686.jpg
# Processed and saved: output_images_1_crop\scene_687.jpg
# Processed and saved: output_images_1_crop\scene_688.jpg
# Processed and saved: output_images_1_crop\scene_689.jpg
# Processed and saved: output_images_1_crop\scene_690.jpg
# Processed and saved: output_images_1_crop\scene_691.jpg
# Processed and saved: output_images_1_crop\scene_692.jpg
# Processed and saved: output_images_1_crop\scene_693.jpg
# Processed and saved: output_images_1_crop\scene_694.jpg
# Processed and saved: output_images_1_crop\scene_695.jpg
# Processed and saved: output_images_1_crop\scene_696.jpg
# Processed and saved: output_images_1_crop\scene_697.jpg
# Processed and saved: output_images_1_crop\scene_698.jpg
# Processed and saved: output_images_1_crop\scene_699.jpg
# Processed and saved: output_images_1_crop\scene_700.jpg
# Processed and saved: output_images_1_crop\scene_701.jpg
# Processed and saved: output_images_1_crop\scene_702.jpg
# Processed and saved: output_images_1_crop\scene_703.jpg
# Processed and saved: output_images_1_crop\scene_704.jpg
# Processed and saved: output_images_1_crop\scene_705.jpg
# Processed and saved: output_images_1_crop\scene_706.jpg
# Processed and saved: output_images_1_crop\scene_707.jpg
# Processed and saved: output_images_1_crop\scene_708.jpg
# Processed and saved: output_images_1_crop\scene_709.jpg
# Processed and saved: output_images_1_crop\scene_710.jpg
# Processed and saved: output_images_1_crop\scene_711.jpg
# Processed and saved: output_images_1_crop\scene_712.jpg
# Processed and saved: output_images_1_crop\scene_713.jpg
# Processed and saved: output_images_1_crop\scene_714.jpg
# Processed and saved: output_images_1_crop\scene_715.jpg
# Processed and saved: output_images_1_crop\scene_716.jpg
# Processed and saved: output_images_1_crop\scene_717.jpg
# Processed and saved: output_images_1_crop\scene_718.jpg
# Processed and saved: output_images_1_crop\scene_719.jpg
# Processed and saved: output_images_1_crop\scene_720.jpg
# Processed and saved: output_images_1_crop\scene_721.jpg
# Processed and saved: output_images_1_crop\scene_722.jpg
# Processed and saved: output_images_1_crop\scene_723.jpg
# Processed and saved: output_images_1_crop\scene_724.jpg
# Processed and saved: output_images_1_crop\scene_725.jpg
# Processed and saved: output_images_1_crop\scene_726.jpg
# Processed and saved: output_images_1_crop\scene_727.jpg
# Processed and saved: output_images_1_crop\scene_728.jpg
# Processed and saved: output_images_1_crop\scene_729.jpg
# Processed and saved: output_images_1_crop\scene_730.jpg
# Processed and saved: output_images_1_crop\scene_731.jpg
# Processed and saved: output_images_1_crop\scene_732.jpg
# Processed and saved: output_images_1_crop\scene_733.jpg
# Processed and saved: output_images_1_crop\scene_734.jpg
# Processed and saved: output_images_1_crop\scene_735.jpg
# Processed and saved: output_images_1_crop\scene_736.jpg
# Processed and saved: output_images_1_crop\scene_737.jpg
# Processed and saved: output_images_1_crop\scene_738.jpg
# Processed and saved: output_images_1_crop\scene_739.jpg
# Processed and saved: output_images_1_crop\scene_740.jpg
# Processed and saved: output_images_1_crop\scene_741.jpg
# Processed and saved: output_images_1_crop\scene_742.jpg
# Processed and saved: output_images_1_crop\scene_743.jpg
# Processed and saved: output_images_1_crop\scene_744.jpg
# Processed and saved: output_images_1_crop\scene_745.jpg
# Processed and saved: output_images_1_crop\scene_746.jpg
# Processed and saved: output_images_1_crop\scene_747.jpg
# Processed and saved: output_images_1_crop\scene_748.jpg
# Processed and saved: output_images_1_crop\scene_749.jpg
# Processed and saved: output_images_1_crop\scene_750.jpg
# Processed and saved: output_images_1_crop\scene_751.jpg
# Processed and saved: output_images_1_crop\scene_752.jpg
# Processed and saved: output_images_1_crop\scene_753.jpg
# Processed and saved: output_images_1_crop\scene_754.jpg
# Processed and saved: output_images_1_crop\scene_755.jpg
# Processed and saved: output_images_1_crop\scene_756.jpg
# Processed and saved: output_images_1_crop\scene_757.jpg
# Processed and saved: output_images_1_crop\scene_758.jpg
# Processed and saved: output_images_1_crop\scene_759.jpg
# Processed and saved: output_images_1_crop\scene_760.jpg
# Processed and saved: output_images_1_crop\scene_761.jpg
# Processed and saved: output_images_1_crop\scene_762.jpg
# Processed and saved: output_images_1_crop\scene_763.jpg
# Processed and saved: output_images_1_crop\scene_764.jpg
# Processed and saved: output_images_1_crop\scene_765.jpg
# Processed and saved: output_images_1_crop\scene_766.jpg
# Processed and saved: output_images_1_crop\scene_767.jpg
# Processed and saved: output_images_1_crop\scene_768.jpg
# Processed and saved: output_images_1_crop\scene_769.jpg
# Processed and saved: output_images_1_crop\scene_770.jpg
# Processed and saved: output_images_1_crop\scene_771.jpg
# Processed and saved: output_images_1_crop\scene_772.jpg
# Processed and saved: output_images_1_crop\scene_773.jpg
# Processed and saved: output_images_1_crop\scene_774.jpg
# Processed and saved: output_images_1_crop\scene_775.jpg
# Processed and saved: output_images_1_crop\scene_776.jpg
# Processed and saved: output_images_1_crop\scene_777.jpg
# Processed and saved: output_images_1_crop\scene_778.jpg
# Processed and saved: output_images_1_crop\scene_779.jpg
# Processed and saved: output_images_1_crop\scene_780.jpg
# Processed and saved: output_images_1_crop\scene_781.jpg
# Processed and saved: output_images_1_crop\scene_782.jpg
# Processed and saved: output_images_1_crop\scene_783.jpg
# Processed and saved: output_images_1_crop\scene_784.jpg
# Processed and saved: output_images_1_crop\scene_785.jpg
# Processed and saved: output_images_1_crop\scene_786.jpg
# Processed and saved: output_images_1_crop\scene_787.jpg
# Processed and saved: output_images_1_crop\scene_788.jpg
# Processed and saved: output_images_1_crop\scene_789.jpg
